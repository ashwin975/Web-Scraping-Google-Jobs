# %% [markdown]
# ## Web Scraping project: Google's Job postings

# %% [markdown]
# This code shows how to scrape google's job posting using python beautiful soup library and selenium.
#
# * 🏆 This could be a great way to scrape job data compared to google's serp api for which you have to pay 🤑 beyond 100 api calls.
#
# * 🦾 Use the data to make your job search easier.
# ---
#
# The XPATHS might change overtime. Use X-path Chrome extension for XPATH selection

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from time import sleep
import urllib.parse
import itertools

def get_all_jobs(driver, role_name, company):
    query = f"https://www.google.com/search?q={role_name}+{company}&ibp=htl;jobs#htivrt=jobs"
    print(query)
    driver.get(query)
    sleep(3)  
    
    scroll_page(driver)
    sleep(2)  
    
    # Find all listings after scrolling # .//li[@data-ved]//div[@role='treeitem']/div/div
    listings = driver.find_elements(By.XPATH, "//div[@role='treeitem']")
    jobs_data = []
    for idx, listing in enumerate(listings):
        if idx == 50:  # Limit to n listings
            break
        listing.click()
        sleep(1)  # Allow time for the job details to load
        job_data = _get_job(driver)
        job_data["role_name"] = role_name
        job_data["company"] = company
        jobs_url = driver.current_url
        jobs_data.append(job_data)
    return jobs_data

def scroll_page(driver):
    driver.maximize_window()
    driver.implicitly_wait(10)
    for i in range(50):
        try:
            element = driver.find_element(By.XPATH, f"(//div[@class='PwjeAc'])[{i + 1}]")
            driver.execute_script("arguments[0].scrollIntoView(true);", element)
            sleep(1)
        except NoSuchElementException:
            print(f"No more listings to scroll. Total listings scrolled: {i}")
            break

    driver.execute_script("arguments[0].scrollIntoView(true);", driver.find_element(By.XPATH, "(//div[@class='PwjeAc'])[1]"))
    
def _get_job(driver):
    job_container = driver.find_element(By.XPATH, '//div[@class="whazf bD1FPe"]')
    job_id = _get_job_id(driver)
    company = _get_company(driver, job_container)
    role = _get_job_role(driver, job_container)
    location = _get_job_location(driver, job_container)
    posted_date = _get_job_posted(driver, job_container)
    description = _get_job_description(driver, job_container)
    current_url = driver.current_url
    return {"id": job_id, "company": company, "role": role, "location": location, "posted_date": posted_date, "description": description, "url": current_url}


def _get_job_id(driver):
    parsed_url = urllib.parse.urlparse(driver.current_url)
    return urllib.parse.parse_qs(parsed_url.fragment)['htidocid'][0]

def _get_company(driver, job_container):
    return job_container.find_element(By.XPATH, '//div[@class="nJlQNd sMzDkb"]').text

def _get_job_role(driver, job_container):
    job_role_element = job_container.find_element(By.XPATH, '//*[@id="tl_ditc"]/div[1]/div[1]/div[1]/div[1]/div[1]/h2[1]')
    return job_role_element.get_attribute('innerText')

def _get_job_location(driver, job_container):
    job_role_element = job_container.find_element(By.XPATH, '//*[@id="tl_ditc"]/div[1]/div[1]/div[1]/div[1]/div[2]/div[2]/div[2]')
    return job_role_element.get_attribute('innerText')

def _get_job_posted(driver, job_container):
    try:
        job_role_element = job_container.find_element(By.XPATH, '//*[@id="tl_ditc"]/div[1]/div[1]/div[3]/div[1]/span[2]/span[1]')
        return job_role_element.get_attribute('innerText')
    except NoSuchElementException:
        return None

def _get_job_description(driver, job_container):
    try:
        expand_description_button = job_container.find_element(By.XPATH, "div/div/div/div/div/div/div[@class='CdXzFe j4kHIf']")
        expand_description_button.click()
        sleep(1)  # Allow time for the description to expand
    except NoSuchElementException:
        pass
    return job_container.find_element(By.XPATH, ".//span[@class='HBvzbc']").text


if __name__ == '__main__':
    driver = webdriver.Chrome()
    role_names = ["AI Jobs"]
    companies = ["Google"]
    data = []
    for role_name, company in itertools.product(role_names, companies):
        data.extend(get_all_jobs(driver, role_name, company))
    driver.quit()

    df = pd.DataFrame(data)
# Out:
# https://www.google.com/search?q=AI Jobs in Google+Google&ibp=htl;jobs#htivrt=jobs
# No more listings to scroll. Total listings scrolled: 42

# %%
df
# Out:
#                           id company  \
# 0   ZuEz7bylo9sxdTWoAAAAAA==  Google
# 1   v5NtqqnTarKvT-lWAAAAAA==  Google
# 2   AQNt0qR9rH5i9eJbAAAAAA==  Google
# 3   53F5gS624DWwDL20AAAAAA==  Google
# 4   Ut63bf0ItbZLg2Z3AAAAAA==  Google
# 5   fFaP5ZpP0pETPXdgAAAAAA==  Google
# 6   5VWZ55Q2KvNDlqu2AAAAAA==  Google
# 7   EslB-HzOHSUr7oH9AAAAAA==  Google
# 8   BUmfM9KqWKOV2F5mAAAAAA==  Google
# 9   d1ZNV4L3Ai7t5bP9AAAAAA==  Google
# 10  Y3KLhReYl2fcpIEcAAAAAA==  Google
# 11  ZC99V3H37IiR1TYVAAAAAA==  Google
# 12  jTrosoUZv2_mKaJjAAAAAA==  Google
# 13  vf-pUC99DDcbXhlKAAAAAA==  Google
# 14  xVenJWr1D1FDpk_VAAAAAA==  Google
# 15  SXdYHHrw0gdV6Q03AAAAAA==  Google
# 16  5pm0emx2ua21L5i-AAAAAA==  Google
# 17  hXhYs28drrl5FqQbAAAAAA==  Google
# 18  Kn2sSg6ZFXt5FtEIAAAAAA==  Google
# 19  -09QSUr6JbT6hz8NAAAAAA==  Google
# 20  2XsRv4-O5RNDaxXCAAAAAA==  Google
# 21  W-zqLLbQmR_U-xhVAAAAAA==  Google
# 22  RuqNRrwPGXegCMH_AAAAAA==  Google
# 23  xnTmsIkZg6dLGL0nAAAAAA==  Google
# 24  CUP_BXNFRPM_0buAAAAAAA==  Google
# 25  SXdYHHrw0gdV6Q03AAAAAA==  Google
# 26  YPRoqy8aAmGouzlrAAAAAA==  Google
# 27  GZFa0DupfliBwIWfAAAAAA==  Google
# 28  qIiGOVFL_KSiHbPJAAAAAA==  Google
# 29  tq6XiolzGDoOCaKQAAAAAA==  Google
# 30  tN8OJ-vFcJXlqoObAAAAAA==  Google
# 31  GZFa0DupfliBwIWfAAAAAA==  Google
# 32  QnAS5_Vt2V0NvdzNAAAAAA==  Google
# 33  v0nrLwOX4-qfGnJxAAAAAA==  Google
# 34  dMfPES48Jb_JZqWPAAAAAA==  Google
# 35  LkFu_m2Mnmdn69yNAAAAAA==  Google
# 36  TqBERYMGySV_-aVDAAAAAA==  Google
# 37  NKSKUXt4Z2U6o4W3AAAAAA==  Google
# 38  6tlR7SGrySvNfjTXAAAAAA==  Google
# 39  sW2PknpFua0_D19VAAAAAA==  Google
# 40  lqSkv-sclCrwXifDAAAAAA==  Google
# 41  NKSKUXt4Z2U6o4W3AAAAAA==  Google
#
#                                                  role  \
# 0    Technical Solutions Consultant, AI, Google Cloud
# 1   Partner Technology Manager, Data Analytics and AI
# 2   Software Engineer, Machine Learning, Infrastru...
# 3   AI Principles Review Specialist, Health Applic...
# 4   Staff Software Engineer, Machine Learning, Goo...
# 5               Product Manager, AI/ML Infrastructure
# 6   Senior Staff Software Engineer, Google Cloud G...
# 7   Field Solutions Developer I, Generative AI, Go...
# 8                AI Engineer, Google Cloud Consulting
# 9   Staff Software Engineer, Google Cloud Generati...
# 10  Field Solutions Architect III, Generative AI, ...
# 11  Director, Product Management, Consumer and AI ...
# 12  Software Developer III, Machine Learning, Goog...
# 13       Go-To-Market Specialist, AI/ML, Google Cloud
# 14  Research Engineer, Computer Vision, Google Res...
# 15   Global Product Solutions Lead, Ads, Cloud and AI
# 16            Google Contact Center AI Implementation
# 17              Head of Responsible AI, Public Sector
# 18  Industry Solutions Consultant, Contact Center ...
# 19                Customer Engineer, AI, Google Cloud
# 20            Integrate AI to Google Geolocation form
# 21                     Customer Engineer, AI/ML, HCLS
# 22  Developer Advocate, AI/ML, Google Cloud at Goo...
# 23  Global Partner Incentives Design Lead, AI, Goo...
# 24  Research Scientist, Quantum Error Correction E...
# 25   Global Product Solutions Lead, Ads, Cloud and AI
# 26       Sustaining Test Systems Engineer, Quantum AI
# 27  Field Solutions Developer II, Generative AI, G...
# 28  Technical Lead, Google Kubernetes Engine, Gene...
# 29  Field Solutions Developer III, Generative AI, ...
# 30  Industry Solution Consultant, Contact Center A...
# 31  Field Solutions Developer II, Generative AI, G...
# 32       Go-To-Market Specialist/ AI/ML/ Google Cloud
# 33       Go-To-Market Specialist, AI/ML, Google Cloud
# 34          AI Sales Specialist Manager, Google Cloud
# 35     Senior Product Manager, Generative AI, Silicon
# 36                             Solutions AI Architect
# 37                   AI Writer, Global Communications
# 38  Quantum Error Correction Research Scientist, Q...
# 39   Global Product Solutions Lead, Ads, Cloud and AI
# 40          AI Sales Specialist Manager, Google Cloud
# 41                   AI Writer, Global Communications
#
#                      location       posted_date  \
# 0                New York, NY       25 days ago
# 1                New York, NY  206K–302K a year
# 2               Sunnyvale, CA        2 days ago
# 3                 Atlanta, GA         1 day ago
# 4           San Francisco, CA       21 days ago
# 5               Sunnyvale, CA       15 days ago
# 6    New York, NY (+5 others)       14 days ago
# 7              Washington, DC       22 days ago
# 8                 Chicago, IL        7 days ago
# 9               Cambridge, MA        4 days ago
# 10          San Francisco, CA        3 days ago
# 11          Mountain View, CA       22 days ago
# 12               Waterloo, IA        5 days ago
# 13    Chicago, IL (+5 others)       16 days ago
# 14          Mountain View, CA      10 hours ago
# 15                Chicago, IL        2 days ago
# 16                   Anywhere        8 days ago
# 17              Sunnyvale, CA         Full-time
# 18                 Austin, TX        3 days ago
# 19               Bee Cave, TX         Full-time
# 20                   Anywhere        7 days ago
# 21                 Irvine, CA       25 days ago
# 22                Seattle, WA        3 days ago
# 23                Chicago, IL       28 days ago
# 24  United States (+3 others)       25 days ago
# 25                Chicago, IL        2 days ago
# 26             Isla Vista, CA       29 days ago
# 27                Atlanta, GA        5 days ago
# 28               Kirkland, WA       16 days ago
# 29                  Miami, FL       28 days ago
# 30     Reston, VA (+3 others)       24 days ago
# 31                Atlanta, GA        5 days ago
# 32               New York, NY        5 days ago
# 33                 Austin, TX       16 days ago
# 34          San Francisco, CA        5 days ago
# 35               Portland, OR        5 days ago
# 36             Washington, DC       16 days ago
# 37          Mountain View, CA        3 days ago
# 38            Los Angeles, CA        4 days ago
# 39            Los Angeles, CA        5 days ago
# 40            Los Angeles, CA        5 days ago
# 41          Mountain View, CA        3 days ago
#
#                                           description  \
# 0   Note: By applying to this position you will ha...
# 1   Minimum qualifications:\n• 10 years of experie...
# 2   Minimum qualifications:\n• Bachelor's degree o...
# 3   Note: By applying to this position you will ha...
# 4   Note: By applying to this position you will ha...
# 5   Minimum qualifications:\n• Bachelor's degree o...
# 6   Minimum qualifications:\n• Bachelor's degree, ...
# 7   The application window will be open until at l...
# 8   Minimum qualifications:\n• Bachelor's degree i...
# 9   The application window will be open until at l...
# 10  Field Solutions Architect III, Generative AI, ...
# 11  Minimum qualifications:\n• 15 years of experie...
# 12  Minimum\nQualifications:\nBachelor's degree or...
# 13  Minimum qualifications:\n• Bachelor's degree o...
# 14  Research Engineer, Computer Vision, Google Res...
# 15  Minimum qualifications:\n• Bachelor's degree o...
# 16  We are looking to implement Google Contact Cen...
# 17  Minimum qualifications:\n• Bachelors degree or...
# 18  Note: By applying to this position you will ha...
# 19  Minimum qualifications:\n• Bachelors degree or...
# 20  I have an existing html form that obtains long...
# 21  The application window will be open until at l...
# 22  Minimum\nQualifications:\nBachelor's degree in...
# 23  Note: By applying to this position you will ha...
# 24  The Google Quantum AI team's mission is to mak...
# 25  Minimum qualifications:\n• Bachelor's degree o...
# 26  Minimum qualifications:\n• Bachelor's degree i...
# 27  Minimum qualifications:\n• Bachelor's degree i...
# 28  The application window will be open until at l...
# 29  The application window will be open until at l...
# 30  Minimum qualifications:\n• Bachelor's degree i...
# 31  Minimum qualifications:\n• Bachelor's degree i...
# 32  Minimum qualifications:\n• Bachelor's degree o...
# 33  The application window will be open until at l...
# 34  Minimum\nQualifications:\nBachelor's degree or...
# 35  Note: By applying to this position you will ha...
# 36  LILT is the leading AI solution for enterprise...
# 37  Note: By applying to this position you will ha...
# 38  Note: By applying to this position you will ha...
# 39  This role may also be located in our Playa Vis...
# 40  Minimum\nQualifications:\nBachelor's degree or...
# 41  Note: By applying to this position you will ha...
#
#                                                   url          role_name
# 0   https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 1   https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 2   https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 3   https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 4   https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 5   https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 6   https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 7   https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 8   https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 9   https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 10  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 11  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 12  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 13  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 14  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 15  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 16  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 17  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 18  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 19  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 20  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 21  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 22  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 23  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 24  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 25  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 26  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 27  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 28  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 29  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 30  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 31  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 32  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 33  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 34  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 35  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 36  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 37  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 38  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 39  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 40  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google
# 41  https://www.google.com/search?q=AI%20Jobs%20in...  AI Jobs in Google

# %% [markdown]
# **References:**
#
# - Adapted from Scraping by AIcore
# - Adapted from Google Serp API
