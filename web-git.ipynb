# %% [markdown]
# ## Web Scraping project: Google's Job postings

# %% [markdown]
# This code shows how to scrape google's job posting using python beautiful soup library and selenium.
#
# * 🏆 This could be a great way to scrape job data compared to google's serp api for which you have to pay 🤑 beyond 100 api calls.
#
# * 🦾 Use the data to make your job search easier.
# ---
#
# The XPATHS might change overtime. Use X-path Chrome extension for XPATH selection

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from time import sleep
import urllib.parse
import itertools

def get_all_jobs(driver, role_name, company):
    query = f"https://www.google.com/search?q={role_name}+{company}&ibp=htl;jobs#htivrt=jobs"
    print(query)
    driver.get(query)
    sleep(3)  
    
    scroll_page(driver)
    sleep(2)  
    
    # Find all listings after scrolling # .//li[@data-ved]//div[@role='treeitem']/div/div
    listings = driver.find_elements(By.XPATH, "//div[@role='treeitem']")
    jobs_data = []
    for idx, listing in enumerate(listings):
        if idx == 50:  # Limit to n listings
            break
        listing.click()
        sleep(1)  # Allow time for the job details to load
        job_data = _get_job(driver)
        job_data["role_name"] = role_name
        job_data["company"] = company
        jobs_url = driver.current_url
        jobs_data.append(job_data)
    return jobs_data

def scroll_page(driver):
    driver.maximize_window()
    driver.implicitly_wait(10)
    for i in range(50):
        try:
            element = driver.find_element(By.XPATH, f"(//div[@class='PwjeAc'])[{i + 1}]")
            driver.execute_script("arguments[0].scrollIntoView(true);", element)
            sleep(1)
        except NoSuchElementException:
            print(f"No more listings to scroll. Total listings scrolled: {i}")
            break

    driver.execute_script("arguments[0].scrollIntoView(true);", driver.find_element(By.XPATH, "(//div[@class='PwjeAc'])[1]"))
    
def _get_job(driver):
    job_container = driver.find_element(By.XPATH, '//div[@class="whazf bD1FPe"]')
    job_id = _get_job_id(driver)
    company = _get_company(driver, job_container)
    role = _get_job_role(driver, job_container)
    location = _get_job_location(driver, job_container)
    posted_date = _get_job_posted(driver, job_container)
    description = _get_job_description(driver, job_container)
    current_url = driver.current_url
    return {"id": job_id, "company": company, "role": role, "location": location, "posted_date": posted_date, "description": description, "url": current_url}


def _get_job_id(driver):
    parsed_url = urllib.parse.urlparse(driver.current_url)
    return urllib.parse.parse_qs(parsed_url.fragment)['htidocid'][0]

def _get_company(driver, job_container):
    return job_container.find_element(By.XPATH, '//div[@class="nJlQNd sMzDkb"]').text

def _get_job_role(driver, job_container):
    job_role_element = job_container.find_element(By.XPATH, '//*[@id="tl_ditc"]/div[1]/div[1]/div[1]/div[1]/div[1]/h2[1]')
    return job_role_element.get_attribute('innerText')

def _get_job_location(driver, job_container):
    job_role_element = job_container.find_element(By.XPATH, '//*[@id="tl_ditc"]/div[1]/div[1]/div[1]/div[1]/div[2]/div[2]/div[2]')
    return job_role_element.get_attribute('innerText')

def _get_job_posted(driver, job_container):
    try:
        job_role_element = job_container.find_element(By.XPATH, '//*[@id="tl_ditc"]/div[1]/div[1]/div[3]/div[1]/span[2]/span[1]')
        return job_role_element.get_attribute('innerText')
    except NoSuchElementException:
        return None

def _get_job_description(driver, job_container):
    try:
        expand_description_button = job_container.find_element(By.XPATH, "div/div/div/div/div/div/div[@class='CdXzFe j4kHIf']")
        expand_description_button.click()
        sleep(1)  # Allow time for the description to expand
    except NoSuchElementException:
        pass
    return job_container.find_element(By.XPATH, ".//span[@class='HBvzbc']").text


if __name__ == '__main__':
    driver = webdriver.Chrome()
    role_names = ["AI Jobs"]
    companies = ["Google"]
    data = []
    for role_name, company in itertools.product(role_names, companies):
        data.extend(get_all_jobs(driver, role_name, company))
    driver.quit()

    df = pd.DataFrame(data)
# Out:
# https://www.google.com/search?q=AI Jobs+Google&ibp=htl;jobs#htivrt=jobs
# No more listings to scroll. Total listings scrolled: 46

# %%
df
# Out:
#                           id company  \
# 0   MFCner5zB6svY4KNAAAAAA==  Google
# 1   oK6V-OJMwuc8EG-ZAAAAAA==  Google
# 2   5VWZ55Q2KvNDlqu2AAAAAA==  Google
# 3   ZuEz7bylo9sxdTWoAAAAAA==  Google
# 4   v5NtqqnTarKvT-lWAAAAAA==  Google
# 5   wCEPMkeCoz6HwczyAAAAAA==  Google
# 6   EslB-HzOHSUr7oH9AAAAAA==  Google
# 7   lqJoixWvd3zbesVsAAAAAA==  Google
# 8   TFLSbILZXCLt7CZ4AAAAAA==  Google
# 9   K158vpyUgcyNRMKQAAAAAA==  Google
# 10  if0UqvpJBkZ06wGlAAAAAA==  Google
# 11  O-lbRnB78taz49JIAAAAAA==  Google
# 12  EmXyhMksoHrG8otAAAAAAA==  Google
# 13  y_pgS1KLTNl8gMqaAAAAAA==  Google
# 14  ZC99V3H37IiR1TYVAAAAAA==  Google
# 15  k-5sQk_GlFkG0XEOAAAAAA==  Google
# 16  e8lgFqkoHzfBYUV1AAAAAA==  Google
# 17  KBfyIzmhXVsAVukNAAAAAA==  Google
# 18  A4IED_WCzbBazQ1VAAAAAA==  Google
# 19  sW2PknpFua0_D19VAAAAAA==  Google
# 20  02WOrVKsiDx8L6tpAAAAAA==  Google
# 21  NEDm1SdKqjZHAh5QAAAAAA==  Google
# 22  j6e0zNjdamXorFoOAAAAAA==  Google
# 23  2VUJSdPjsD3ZuRodAAAAAA==  Google
# 24  Tf1tTb2-fsmjM8kyAAAAAA==  Google
# 25  5pm0emx2ua21L5i-AAAAAA==  Google
# 26  fFaP5ZpP0pETPXdgAAAAAA==  Google
# 27  t37dUeaDA1yirBnhAAAAAA==  Google
# 28  pztaUBjp2KwZrIscAAAAAA==  Google
# 29  MMe0E3WvQH8gNrGsAAAAAA==  Google
# 30  jz21octJoAryt1tOAAAAAA==  Google
# 31  hXhYs28drrl5FqQbAAAAAA==  Google
# 32  v0nrLwOX4-qfGnJxAAAAAA==  Google
# 33  vf-pUC99DDcbXhlKAAAAAA==  Google
# 34  6tlR7SGrySvNfjTXAAAAAA==  Google
# 35  fYJRUPF8EeF0rx_SAAAAAA==  Google
# 36  9pKeBmeXzdFixXKVAAAAAA==  Google
# 37  W5K4khanTxJ0vRFiAAAAAA==  Google
# 38  RuqNRrwPGXegCMH_AAAAAA==  Google
# 39  xFBLUVvom7URdYLrAAAAAA==  Google
# 40  tq6XiolzGDoOCaKQAAAAAA==  Google
# 41  BM64EFb0jt3o-d6HAAAAAA==  Google
# 42  YH4_7EGsH4jsxffKAAAAAA==  Google
# 43  53F5gS624DWwDL20AAAAAA==  Google
# 44  -09QSUr6JbT6hz8NAAAAAA==  Google
# 45  CUP_BXNFRPM_0buAAAAAAA==  Google
#
#                                                  role  \
# 0   Staff Software Engineer Google Cloud Generativ...
# 1   Software Engineer III, Machine Learning, Googl...
# 2   Staff Software Engineer, Google Cloud Generati...
# 3    Technical Solutions Consultant, AI, Google Cloud
# 4   Partner Technology Manager, Data Analytics and AI
# 5                    AI Writer, Global Communications
# 6   Field Solutions Developer I, Generative AI, Go...
# 7              AI Consultant, Google Cloud Consulting
# 8   Senior Staff Technical Solutions Consultant, G...
# 9   Field Solutions Developer IV, Generative AI, G...
# 10      AI Chatbot that exports text into Google docs
# 11  Senior Staff Software Engineer, Generative AI,...
# 12  Expert Google Vertex AI Developer for Document...
# 13  Technical Lead, Google Kubernetes Engine, Gene...
# 14  Director, Product Management, Consumer and AI ...
# 15  Field Solutions Developer II, Generative AI, G...
# 16    Startups Customer Engineer, AI/ML, Google Cloud
# 17                                      AI Researcher
# 18  Teach GCP Google Cloud Platform Machine Learni...
# 19   Global Product Solutions Lead, Ads, Cloud and AI
# 20  Research Scientist, Electromagnetic Modeling a...
# 21  Business Excellence Lead, AI and Enablement, G...
# 22  Decision Scientist, Revenue Acceleration, Goog...
# 23                             Solutions AI Architect
# 24  Senior Staff Software Engineer, Machine Learni...
# 25            Google Contact Center AI Implementation
# 26              Product Manager, AI/ML Infrastructure
# 27  Senior Product Manager, Natural Language Proce...
# 28  Staff Software Engineer, Machine Learning Infr...
# 29  Staff Software Engineer, Generative AI, Chrome...
# 30  Senior Staff Technical Solutions Consultant/ G...
# 31              Head of Responsible AI, Public Sector
# 32       Go-To-Market Specialist, AI/ML, Google Cloud
# 33       Go-To-Market Specialist, AI/ML, Google Cloud
# 34  Quantum Error Correction Research Scientist, Q...
# 35  Engineering Analyst Technical Lead, Cloud AI P...
# 36  Research Scientist, System Optimization and St...
# 37  Senior Software Engineer, Full Stack, Google C...
# 38  Developer Advocate, AI/ML, Google Cloud at Goo...
# 39  Business Excellence Lead, AI and Enablement, G...
# 40  Field Solutions Developer III, Generative AI, ...
# 41       Sustaining Test Systems Engineer, Quantum AI
# 42          AI Sales Specialist Manager, Google Cloud
# 43  AI Principles Review Specialist, Health Applic...
# 44                Customer Engineer, AI, Google Cloud
# 45  Quantum Error Correction Research Scientist, Q...
#
#                    location       posted_date  \
# 0               Buffalo, NY        6 days ago
# 1              New York, NY        7 days ago
# 2              New York, NY       15 days ago
# 3              New York, NY         Full-time
# 4              New York, NY  206K–302K a year
# 5             United States       16 days ago
# 6            Washington, DC         Full-time
# 7                Reston, VA        5 days ago
# 8            Pittsburgh, PA        6 days ago
# 9              New York, NY       13 days ago
# 10                 Anywhere        2 days ago
# 11             Kirkland, WA        8 days ago
# 12                 Anywhere        4 days ago
# 13           Washington, DC         1 day ago
# 14        Mountain View, CA         Full-time
# 15           Washington, DC         1 day ago
# 16               Colton, TX       19 days ago
# 17                 Anywhere              None
# 18                 Anywhere        6 days ago
# 19              Chicago, IL       16 days ago
# 20           Isla Vista, CA        8 days ago
# 21            United States        9 days ago
# 22               Austin, TX  120K–190K a year
# 23             New York, NY       28 days ago
# 24              Seattle, WA       20 days ago
# 25                 Anywhere       19 days ago
# 26            Sunnyvale, CA       27 days ago
# 27            United States       14 days ago
# 28        Mountain View, CA        3 days ago
# 29   Seattle, WA (+1 other)       23 days ago
# 30             New York, NY        3 days ago
# 31            Sunnyvale, CA         Full-time
# 32               Austin, TX       28 days ago
# 33  Chicago, IL (+5 others)       28 days ago
# 34          Los Angeles, CA       14 days ago
# 35              Seattle, WA        6 days ago
# 36          Los Angeles, CA       12 days ago
# 37            Sunnyvale, TX        7 days ago
# 38              Seattle, WA         1 day ago
# 39               Colton, TX        9 days ago
# 40                Miami, FL         Full-time
# 41               Goleta, CA        7 days ago
# 42             Bee Cave, TX         Full-time
# 43              Atlanta, GA       13 days ago
# 44             Bee Cave, TX         Full-time
# 45               Goleta, CA       13 days ago
#
#                                           description  \
# 0   A company is looking for a Staff Software Engi...
# 1   Minimum qualifications:\n• Bachelor’s degree o...
# 2   The application window will be open until at l...
# 3   Note: By applying to this position you will ha...
# 4   Minimum qualifications:\n• 10 years of experie...
# 5   Note: By applying to this position you will ha...
# 6   The application window will be open until at l...
# 7   The application window will be open until at l...
# 8   The application window will be open until at l...
# 9   X\n\nFor US Applcants Only\n\nThis role may al...
# 10  Dear potential candidate,\n\nI'm seeking an de...
# 11  Senior Staff Software Engineer, Generative AI,...
# 12  Project Overview:\n\nWe're seeking a skilled G...
# 13  Minimum qualifications:Bachelor's degree or eq...
# 14  Minimum qualifications:\n• 15 years of experie...
# 15  Minimum qualifications:Bachelor's degree in Sc...
# 16  X\n\nThis role may also be located in our Play...
# 17  Here at Fireworks, we’re building the future o...
# 18  Need a tutor to teach the following topics:\n\...
# 19  Minimum qualifications:\n• Bachelor's degree o...
# 20  Minimum qualifications:\n• PhD in Electrical E...
# 21  Minimum qualifications:\n• Bachelor’s degree o...
# 22  Minimum qualifications:\n• Master's degree in ...
# 23  LILT is the leading AI solution for enterprise...
# 24  The application window will be open until at l...
# 25  We are looking to implement Google Contact Cen...
# 26  Minimum qualifications:\n• Bachelor's degree o...
# 27  Minimum qualifications:\n• Bachelor’s degree o...
# 28  Minimum\nQualifications:\nBachelor's degree or...
# 29  Minimum qualifications:\n• Bachelor's degree o...
# 30  Senior Staff Technical Solutions Consultant, G...
# 31  Minimum qualifications:\n• Bachelors degree or...
# 32  The application window will be open until at l...
# 33  Minimum qualifications:\n• Bachelor's degree o...
# 34  Note: By applying to this position you will ha...
# 35  Minimum qualifications:\n• Bachelor's degree o...
# 36  Note: By applying to this position you will ha...
# 37  Minimum qualifications:Bachelor’s degree or eq...
# 38  Minimum\nQualifications:\nBachelor's degree in...
# 39  XThe application window will be open until at ...
# 40  The application window will be open until at l...
# 41  Minimum qualifications:\n• Bachelor's degree i...
# 42  Minimum qualifications:\n• Bachelors degree or...
# 43  Note: By applying to this position you will ha...
# 44  Minimum qualifications:\n• Bachelors degree or...
# 45  Note: By applying to this position you will ha...
#
#                                                   url role_name
# 0   https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 1   https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 2   https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 3   https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 4   https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 5   https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 6   https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 7   https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 8   https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 9   https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 10  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 11  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 12  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 13  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 14  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 15  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 16  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 17  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 18  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 19  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 20  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 21  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 22  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 23  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 24  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 25  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 26  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 27  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 28  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 29  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 30  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 31  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 32  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 33  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 34  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 35  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 36  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 37  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 38  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 39  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 40  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 41  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 42  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 43  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 44  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs
# 45  https://www.google.com/search?q=AI%20Jobs+Goog...   AI Jobs

# %% [markdown]
# ### This code shows how to scrape google's job posting using python with google search api,
#  - You need to create an api key to run this code

# %%
import requests

url = "https://www.searchapi.io/api/v1/search"
params = {
  "engine": "google_jobs",
  "q": "Google Jobs, usa",
  "location": "United States",
  "api_key": "Wc6TG5r5ixSPzTeFG7RhhXZy",
  "hl": "en",
  "gl": "us",
  "num": 10,
  "chips": "state:qaUj8fBLzExnlRjewcbP3Q==,employment_type:FULLTIME"
}

# Make 30 requests to retrieve 300 results
all_results = []
for i in range(0, 100, 10):
    params["start"] = i
    response = requests.get(url, params=params)
    results = response.json()["jobs"]
    all_results.extend(results)

# Print the number of results retrieved
print(len(all_results))
# Out:
# 100

# %%
import pandas as pd

jobs = []

for job in all_results:
    title = job.get('title')
    company_name = job.get('company_name')
    salary = job.get('detected_extensions', {}).get('salary')
    posted_at = job.get('detected_extensions', {}).get('posted_at')
    web_url_link = job.get('apply_link')
    job_description = job.get('description')
    company_web_results_link = job.get('company_web_results_link')
    via = job.get('via')
    company_website = job.get('company_website')
    location = job.get('location')

    via_list = []
    if via:
        if isinstance(via, list):
            via_list.extend(via)
        else:
            via_list.append(via)

    for via_item in via_list:
        via_element = {'Title': title,
                       'Company Name': company_name,
                       'Salary': salary,
                       'Posted At': posted_at,
                       'Web URL Link': web_url_link,
                       'Job Description': job_description,
                       'Company Web Results Link': company_web_results_link,
                       'Via': via_item,
                       'Company Website': company_website,
                       'Location': location
                      }
        jobs.append(via_element)

df102 = pd.DataFrame(jobs)
df102
# Out:
#                                                 Title Company Name  \
# 0              Software Engineer III, Privacy Sandbox       Google
# 1   Director, Global Communications Industry, Goog...       Google
# 2            Data Engineer, Google Customer Solutions       Google
# 3   Software Development Manager II, Development P...       Google
# 4          Strategy and Operations Lead, Go-To-Market       Google
# ..                                                ...          ...
# 95  Group Product Manager, Machine Learning, Frame...       Google
# 96  Staff Software Engineer, Applied Science, Core...       Google
# 97      Manager, Partnerships Strategy and Operations       Google
# 98  Small/Medium Business Program Manager, Google ...   Google LLC
# 99  Technical Program Manager, Infrastructure Supp...       Google
#
#               Salary    Posted At  \
# 0               None    1 day ago
# 1               None   1 hour ago
# 2               None   2 days ago
# 3               None    1 day ago
# 4               None    1 day ago
# ..               ...          ...
# 95              None  7 hours ago
# 96     20–28 an hour   6 days ago
# 97              None   2 days ago
# 98  142K–211K a year   5 days ago
# 99              None   6 days ago
#
#                                          Web URL Link  \
# 0   https://www.linkedin.com/jobs/view/software-en...
# 1   https://www.linkedin.com/jobs/view/director-gl...
# 2   https://www.linkedin.com/jobs/view/data-engine...
# 3   https://www.linkedin.com/jobs/view/software-de...
# 4   https://www.linkedin.com/jobs/view/strategy-an...
# ..                                                ...
# 95  https://www.linkedin.com/jobs/view/group-produ...
# 96  https://geebo.com/jobs-online/view/id/10217943...
# 97  https://www.linkedin.com/jobs/view/manager-par...
# 98  https://www.jobserve.com/us/en/extjob/SMALL-ME...
# 99  https://www.linkedin.com/jobs/view/technical-p...
#
#                                       Job Description  \
# 0   Note: By applying to this position you will ha...
# 1   Note: By applying to this position you will ha...
# 2   This role may also be located in our Playa Vis...
# 3   Note: By applying to this position you will ha...
# 4   This role may also be located in our Playa Vis...
# ..                                                ...
# 95  Note: By applying to this position you will ha...
# 96  Minimum\nQualifications:\nBachelor's degree or...
# 97  This role may also be located in our Playa Vis...
# 98  XNote: By applying to this position you will h...
# 99  Note: By applying to this position you will ha...
#
#                              Company Web Results Link           Via  \
# 0   https://www.google.com/search?sca_esv=298519f3...  via LinkedIn
# 1   https://www.google.com/search?sca_esv=298519f3...  via LinkedIn
# 2   https://www.google.com/search?sca_esv=298519f3...  via LinkedIn
# 3   https://www.google.com/search?sca_esv=298519f3...  via LinkedIn
# 4   https://www.google.com/search?sca_esv=298519f3...  via LinkedIn
# ..                                                ...           ...
# 95  https://www.google.com/search?sca_esv=298519f3...  via LinkedIn
# 96  https://www.google.com/search?sca_esv=298519f3...     via Geebo
# 97  https://www.google.com/search?sca_esv=298519f3...  via LinkedIn
# 98  https://www.google.com/search?sca_esv=298519f3...  via JobServe
# 99  https://www.google.com/search?sca_esv=298519f3...  via LinkedIn
#
#            Company Website           Location
# 0   http://www.google.com/       Kirkland, WA
# 1   http://www.google.com/  San Francisco, CA
# 2   http://www.google.com/        Chicago, IL
# 3   http://www.google.com/        Seattle, WA
# 4   http://www.google.com/     Washington, DC
# ..                     ...                ...
# 95  http://www.google.com/      Sunnyvale, CA
# 96  http://www.google.com/       Kirkland, WA
# 97  http://www.google.com/       New York, NY
# 98  http://www.google.com/        Chicago, IL
# 99  http://www.google.com/       New York, NY
#
# [100 rows x 10 columns]

# %% [markdown]
# **References:**
#
# - Adapted from Scraping by AIcore
# - Adapted from Google Serp API
